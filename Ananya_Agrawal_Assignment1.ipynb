# %% [markdown]
# ## Try PCA from scratch - 6 lines of code - extra points, else scikit package can be used -> no extra points!!

# %%
# %pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 33.9 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 32.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df=pd.read_csv("/Users/ananyaagrawal/Desktop/CMU Sem 1/38615-Computational Modelling-ML for Science/Assignment/hw1_dataset.csv")

# %%
df
# Out:
#       experimental_proprty          MS_enc  nHetero  nX  C2SP3  MPC5  \
# 0                     3.54  PPENPINEAPLE42        5   1      0    83
# 1                    -1.18  PPENPINEAPLE42       11   0      3   114
# 2                     3.69  PPENPINEAPLE42        5   1      2    69
# 3                     3.37  HTXPTDWTTWOBJR        9   1      3   105
# 4                     3.10  PPENPINEAPLE42        7   0      2    68
# ...                    ...             ...      ...  ..    ...   ...
# 1995                  2.06  PPENPINEAPLE42       12   2      5   111
# 1996                  3.03  PPENPINEAPLE42        6   2      2    66
# 1997                  3.80  VMZXVMIGMRZLPU        9   0      0    74
# 1998                  3.22  HTXPTDWTTWOBJR        9   1      2   103
# 1999                  1.75  PPENPINEAPLE42        7   1      0    86
#
#              ATS0i  NaasN     SsCH3  nCl  ...     AATS0Z   ATSC0are   ATSC2pe  \
# ...

# %%
df.describe()
# Out:
#        experimental_proprty     nHetero           nX        C2SP3  \
# count           2000.000000  2000.00000  2000.000000  2000.000000
# mean               2.170570     7.16850     0.777000     2.197000
# std                1.207616     2.80536     1.131774     2.464595
# min               -1.500000     1.00000     0.000000     0.000000
# 25%                1.370000     5.00000     0.000000     0.000000
# 50%                2.340000     7.00000     0.000000     2.000000
# 75%                3.100000     9.00000     1.000000     3.000000
# max                4.500000    34.00000     9.000000    27.000000
#
#               MPC5         ATS0i        NaasN        SsCH3          nCl  \
# count  2000.000000   2000.000000  2000.000000  2000.000000  2000.000000
# mean     87.181500   7900.675402     0.320000     2.492567     0.310500
# std      32.645987   2509.808249     0.608099     2.618002     0.611782
# min       5.000000   2046.021324     0.000000     0.000000     0.000000
# ...
